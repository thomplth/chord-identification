# %%
# from ..ChordNoteTickStart.constant import MAJOR_SEMITONE_CUMULATIVE_PATTERN
from Music21Utils.music21_utility import *
from metric import *
from piece import Piece
import music21

# TODO: transfer the lyrics from the old file to the new file
# filename = "Nocturne_in_E_Major"
# filename = "Chopin_F._Nocturne_in_E_Major,_Op.26_No.2"
# stream = load_file("../Minuet_in_F_C.mxl")
stream = load_file("../data/anonymous_Twinkle_Twinkle.mxl")

chordify_stream = chordify(stream)
measures_len = len(get_measures(chordify_stream))
print(measures_len)
time_signature = get_initial_time_signature(chordify_stream)
print(time_signature.numerator)


for element in stream.recurse().getElementsByClass("Measure"):
    text = element.show("text")
    notes = element.recurse().getElementsByClass("Note")
    if len(notes) > 0:
        # notes[0].addLyric(str("x"))
        for note in notes:
            mark = int(note.offset) - note.offset % time_signature.numerator == 0
            # mark = mark and int(note.offset) % time_signature.numerator
            if mark:
                note.addLyric(str("x"))

    print("----")

# export_file(stream, "../result/Minuet_in_F_C_test")
export_file(stream, "../result/anonymous_Twinkle_Twinkle_test")
# Out:
# 24
# 4
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.clef.TrebleClef>
# {0.0} <music21.key.KeySignature of no sharps or flats>
# {0.0} <music21.meter.TimeSignature 4/4>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note C>
# {1.0} <music21.note.Note C>
# {2.0} <music21.note.Note G>
# {3.0} <music21.note.Note G>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note A>
# {1.0} <music21.note.Note A>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note G>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note F>
# {1.0} <music21.note.Note F>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note E>
# {3.0} <music21.note.Note E>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note D>
# {1.0} <music21.note.Note D>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note C>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note G>
# {1.0} <music21.note.Note G>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note F>
# {3.0} <music21.note.Note F>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note E>
# {1.0} <music21.note.Note E>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note D>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note G>
# {1.0} <music21.note.Note G>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note F>
# {3.0} <music21.note.Note F>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note E>
# {1.0} <music21.note.Note E>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note D>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note C>
# {1.0} <music21.note.Note C>
# {2.0} <music21.note.Note G>
# {3.0} <music21.note.Note G>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note A>
# {1.0} <music21.note.Note A>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note G>
# ----
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note F>
# {1.0} <music21.note.Note F>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note E>
# {3.0} <music21.note.Note E>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note D>
# {1.0} <music21.note.Note E>
# {2.0} <music21.harmony.ChordSymbol F>
# {2.0} <music21.note.Note F>
# {3.0} <music21.note.Note G>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note F>
# {1.0} <music21.note.Note F>
# {2.0} <music21.note.Note C>
# {3.0} <music21.note.Note C>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note D>
# {1.0} <music21.note.Note D>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note C>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note B->
# {1.0} <music21.note.Note B->
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note A>
# {3.0} <music21.note.Note A>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note G>
# {1.0} <music21.note.Note G>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note F>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note C>
# {1.0} <music21.note.Note C>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note B->
# {3.0} <music21.note.Note B->
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note A>
# {1.0} <music21.note.Note A>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note G>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note C>
# {1.0} <music21.note.Note C>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note B->
# {3.0} <music21.note.Note B->
# ----
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note A>
# {1.0} <music21.note.Note A>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note G>
# ----
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note F>
# {1.0} <music21.note.Note F>
# {2.0} <music21.note.Note C>
# {3.0} <music21.note.Note C>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note D>
# {1.0} <music21.note.Note D>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note C>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note B->
# {1.0} <music21.note.Note B->
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note A>
# {3.0} <music21.note.Note A>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.note.Note G>
# {1.0} <music21.note.Note G>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.note.Note F>
# {4.0} <music21.bar.Barline type=final>
# ----
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.layout.StaffLayout distance 81.16, staffNumber 2, staffSize None, staffLines None>
# {0.0} <music21.clef.BassClef>
# {0.0} <music21.key.KeySignature of no sharps or flats>
# {0.0} <music21.meter.TimeSignature 4/4>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord C3 E3 G3>
# {2.0} <music21.chord.Chord C3 E3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord C3 F3 A3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord C3 E3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord B2 D3 G3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord C3 E3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord B2 D3 G3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord C3 E3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord E3 G3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord D3 G3 B3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord C3 E3 G3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord B2 F3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord E3 G3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord D3 G3 B3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord C3 E3 G3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord B2 F3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord C3 E3 G3>
# {2.0} <music21.chord.Chord E3 G3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 A3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord E3 G3 C4>
# ----
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.layout.StaffLayout distance 88.96, staffNumber 2, staffSize None, staffLines None>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord D3 G3 B3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord C3 E3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord B2 F3 G3>
# {2.0} <music21.harmony.ChordSymbol F>
# {2.0} <music21.chord.Chord C3 E3 B-3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 A3 C4>
# {2.0} <music21.chord.Chord F3 A3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 B-3 D4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 A3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord E3 G3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 A3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord C3 E3 G3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 A3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 A3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 B-3 D4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 A3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord C3 E3 G3>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 A3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 B-3 D4>
# ----
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.layout.StaffLayout distance 70.45, staffNumber 2, staffSize None, staffLines None>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 A3 C4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord C3 E3 G3>
# ----
# {0.0} <music21.layout.SystemLayout>
# {0.0} <music21.layout.StaffLayout distance 85.3, staffNumber 2, staffSize None, staffLines None>
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 A3 C4>
# {2.0} <music21.chord.Chord F3 A3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 B-3 D4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 A3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord F3 B-3 D4>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 A3 C4>
# ----
# {0.0} <music21.harmony.ChordSymbol C>
# {0.0} <music21.chord.Chord C3 E3 B-3>
# {2.0} <music21.harmony.ChordSymbol C>
# {2.0} <music21.chord.Chord F3 A3 C4>
# {4.0} <music21.bar.Barline type=final>
# ----

# %%
elements = list(stream.recurse().getElementsByClass("Measure"))

# %%
notes = elements[0].recurse().getElementsByClass("Note")

# %%
notes[0]
# Out:
# <music21.note.Note C>

# %%
ans = [('CM(I)', 0.0), ('CM(IV)', 4.0), ('CM(I)', 6.0), ('CM(V)', 8.0), ('CM(I)', 10.0), ('CM(V)', 12.0), ('CM(I)', 14.0), ('CM(I)', 16.0), ('CM(V)', 18.0), ('CM(I)', 20.0), ('CM(V)', 22.0), ('CM(I)', 24.0), ('CM(V)', 26.0), ('CM(I)', 28.0), ('CM(V)', 30.0), ('CM(I)', 32.0), ('CM(IV)', 36.0), ('CM(I)', 38.0), ('CM(V)', 40.0), ('CM(I)', 42.0), ('CM(V)', 44.0), ('FM(V)', 46.0), ('FM(I)', 48.0), ('FM(IV)', 52.0), ('FM(I)', 54.0), ('FM(V)', 56.0), ('FM(I)', 58.0), ('FM(V)', 60.0), ('FM(I)', 62.0), ('FM(I)', 64.0), ('FM(IV)', 66.0), ('FM(I)', 68.0), ('FM(V)', 70.0), ('FM(I)', 72.0), ('FM(IV)', 74.0), ('FM(I)', 76.0), ('FM(V)', 78.0), ('FM(I)', 80.0), ('FM(IV)', 84.0), ('FM(I)', 86.0), ('FM(IV)', 88.0), ('FM(I)', 90.0), ('FM(V)', 92.0), ('FM(I)', 94.0)]

# %%
len(ans)
# Out:
# 44

# %%
ans
# Out:
# [('CM(I)', 0.0),
#  ('CM(IV)', 4.0),
#  ('CM(I)', 6.0),
#  ('CM(V)', 8.0),
#  ('CM(I)', 10.0),
#  ('CM(V)', 12.0),
#  ('CM(I)', 14.0),
#  ('CM(I)', 16.0),
#  ('CM(V)', 18.0),
#  ('CM(I)', 20.0),
#  ('CM(V)', 22.0),
#  ('CM(I)', 24.0),
#  ('CM(V)', 26.0),
#  ('CM(I)', 28.0),
#  ('CM(V)', 30.0),
#  ('CM(I)', 32.0),
#  ('CM(IV)', 36.0),
#  ('CM(I)', 38.0),
#  ('CM(V)', 40.0),
#  ('CM(I)', 42.0),
#  ('CM(V)', 44.0),
#  ('FM(V)', 46.0),
#  ('FM(I)', 48.0),
#  ('FM(IV)', 52.0),
#  ('FM(I)', 54.0),
#  ('FM(V)', 56.0),
#  ('FM(I)', 58.0),
#  ('FM(V)', 60.0),
#  ('FM(I)', 62.0),
#  ('FM(I)', 64.0),
#  ('FM(IV)', 66.0),
#  ('FM(I)', 68.0),
#  ('FM(V)', 70.0),
#  ('FM(I)', 72.0),
#  ('FM(IV)', 74.0),
#  ('FM(I)', 76.0),
#  ('FM(V)', 78.0),
#  ('FM(I)', 80.0),
#  ('FM(IV)', 84.0),
#  ('FM(I)', 86.0),
#  ('FM(IV)', 88.0),
#  ('FM(I)', 90.0),
#  ('FM(V)', 92.0),
#  ('FM(I)', 94.0)]
